# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_excel("Travel_H.xlsx")

# %%
col_entries = ['User', 'Stay Length', 'numeric_staylength', 'Location', 'Feature of Attraction', 'Region', 'pricecategory_trip', 'Trip Expenses', 'pricecategory_travel','Ticket Prices', 'Total Expenses','Time of the Year', 'Circumambience', 'numeric_circumambience']
df=pd.read_excel("Travel_H.xlsx", names=col_entries, header=None, sheet_name=1)
df.head(5)
# Out:
#    User  Stay Length  numeric_staylength          Location  \
# 0  User  Stay Length  numeric_staylength          Location
# 1   159       1 week                   7  Washington, D.C.
# 2   104      2 weeks                  14         Nashville
# 3   299      2 weeks                  14  Washington, D.C.
# 4    42      1 month                  30          Victoria
#
#    Feature of Attraction         Region  pricecategory_trip  Trip Expenses  \
# 0  Feature of Attraction         Region  pricecategory_trip  Trip Expenses
# 1                 Modern  North America                   3          14028
# 2                 Modern  North America                   2           1820
# 3                 Modern  North America                   1           3864
# 4             Historical  North America                   1           1920
#
#    pricecategory_travel  Ticket Prices  Total Expenses  Time of the Year  \
# 0  pricecategory_travel  Ticket Prices  Total Expenses  Time of the Year
# ...

# %%
df.drop([0])
# Out:
#      User Stay Length numeric_staylength            Location  \
# 1     159      1 week                  7    Washington, D.C.
# 2     104     2 weeks                 14           Nashville
# 3     299     2 weeks                 14    Washington, D.C.
# 4      42     1 month                 30            Victoria
# 5     143      3 days                  3          Copenhagen
# 6     104      1 week                  7              Geneva
# 7      41      3 days                  3           Edinburgh
# 8     186      3 days                  3           Amsterdam
# 9     200      1 week                  7              Venice
# 10     12     1 month                 30              Naples
# 11    216      3 days                  3               Salem
# 12    264      1 week                  7               Porto
# 13    293      3 days                  3     Northern Rivers
# 14     36     2 weeks                 14           Vancouver
# ...
